# %%
g_high = [0.1285,0.1385,0.1485,0.1585,0.1685,0.1785,0.1885,0.1985,0.2085,0.2185]
g_stable = [-0.0316, -0.0216, -0.0116,  -0.0016, 0.0116, 0.0216, 0.0316, 0.0416, 0.0516, 0.0616, 0.0716]
WACC_mu = 0.0855
EBIT2024 = 39531
Dep_2025 = 16218
CapEx_2025 = -60851
NWCT2025 = -2819
tax = 0.12
CF = [22081,34453,41757,78499]
CF2021 = 66303
CF2022 = 79580
CF2023 = 92858
CF2024 = 106135
k = 1

#g_high = high_growth_mu + 1
WACC = WACC_mu


for j in g_high:
    CF2025 = EBIT2024*j + Dep_2025 - CapEx_2025 - NWCT2025

    for i in g_stable:
        Firmvalue1 = (CF2021/(k+WACC) + CF2022/((k+WACC)**2) + CF2023/((k+WACC)**3) + CF2024/((k+WACC)**4) + CF2025/((WACC- i)*(k+WACC)**4))/510 
        print(Firmvalue1)
# Out:
# 1569.157412486653
# 1664.8367546099616
# 1780.2234792509455
# 1922.105433430616
# 2168.1851875729267
# 2422.293721098265
# 2770.691135338016
# 3277.8117451311823
# 4084.1185553922937
# 5565.1590980894825
# 9177.193227401327
# 1573.9249203532634
# 1670.0494079356397
# 1785.9729660808127
# 1928.5150220779192
# 2175.7396553832123
# 2431.0304217427115
# 2781.0487451929343
# 3290.5287194177454
# 4100.586849527401
# 5588.517891862709
# 9217.35690878119
# 1578.6924282198745
# 1675.2620612613177
# 1791.72245291068
# 1934.9246107252227
# 2183.2941231934983
# 2439.767122387158
# 2791.406355047853
# 3303.2456937043085
# 4117.055143662507
# 5611.876685635935
# 9257.520590161055
# 1583.4599360864852
# 1680.474714586996
# 1797.4719397405472
# 1941.334199372526
# 2190.848591003784
# 2448.503823031604
# 2801.7639649027715
# 3315.962667990871
# 4133.523437797613
# 5635.2354794091625
# 9297.68427154092
# 1588.2274439530959
# 1685.687367912674
# 1803.2214265704147
# 1947.7437880198293
# 2198.40305881407
# 2457.24052367605
# 2812.1215747576907
# 3328.679642277434
# 4149.99173193272
# 5658.594273182389
# 9337.847952920785
# 1592.9949518197066
# 1690.900021238352
# 1808.970913400282
# 1954.1533766671325
# 2205.957526624355
# 2465.9772243204966
# 2822.479184612609
# 3341.396616563997
# 4166.460026067827
# 5681.953066955615
# 9378.011634300648
# 1597.7624596863172
# 1696.11267456403
# 1814.7204002301492
# 1960.5629653144358
# 2213.5119944346416
# 2474.713924964943
# 2832.8367944675283
# 3354.113590850561
# 4182.928320202935
# 5705.3118607288425
# 9418.175315680515
# 1602.529967552928
# 1701.325327889708
# 1820.4698870600164
# 1966.972553961739
# 2221.066462244927
# 2483.4506256093896
# 2843.1944043224466
# 3366.830565137124
# 4199.396614338041
# 5728.67065450207
# 9458.33899706038
# 1607.2974754195386
# 1706.5379812153865
# 1826.2193738898839
# 1973.3821426090424
# 2228.6209300552127
# 2492.1873262538356
# 2853.5520141773654
# 3379.547539423687
# 4215.864908473148
# 5752.029448275296
# 9498.502678440245
# 1612.0649832861493
# 1711.7506345410643
# 1831.9688607197515
# 1979.7917312563457
# 2236.175397865499
# 2500.9240268982817
# 2863.9096240322842
# 3392.26451371025
# 4232.333202608254
# 5775.388242048522
# 9538.666359820108

# %%
import numpy as np
import math
Reinvestment = (107.84, 41.37, 31.88, 144.65)
ROC = (16.55, 16.83, 20.02, 9.77)
g = (17.85, 6.96, 6.38, 14.13)
a1 = np.mean(Reinvestment)
a2 = np.std(Reinvestment)
b1 = np.mean(ROC)
b2 = np.std(ROC)
c1 = np.mean(g)
c2 = np.std(g)
print(a1)
print(a2)
print(b1)
print(b2)
print(c1)
print(c2)
# Out:
# 81.435
# 46.78210795806448
# 15.792499999999997
# 3.734718028178299
# 11.33
# 4.846385250885448
